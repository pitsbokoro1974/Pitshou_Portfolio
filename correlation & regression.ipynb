# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

x = pd.read_csv('Unit04 Global_GDP.csv')
y = pd.read_csv('Unit04 Global_Population.csv')


y.head()
# Out:
#                   Country Name Country Code        Series Name  Series Code  \
# 0                        Aruba          ABW  Population, total  SP.POP.TOTL
# 1                  Afghanistan          AFG  Population, total  SP.POP.TOTL
# 2  Africa Eastern and Southern          AFE  Population, total  SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total  SP.POP.TOTL
# 4                      Albania          ALB  Population, total  SP.POP.TOTL
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0      54211      55438      56225      56695      57032      57360  ...
# 1    8996967    9169406    9351442    9543200    9744772    9956318  ...
# 2  130836765  134159786  137614644  141202036  144920186  148769974  ...
# 3   96396419   98407221  100506960  102691339  104953470  107289875  ...
# 4    1608800    1659800    1711319    1762621    1814135    1864791  ...
#
# ...

# %%
#drop the missing values 
x.dropna(axis=0, inplace=True)
y.dropna(axis=0, inplace=True)

# %%
#drop uncommon identifiers
x = x.drop(labels=['Indicator Name', 'Indicator Code'], axis=1)
y = y.drop(labels=['Series Name', 'Series Code'], axis=1)

# %%
x
# Out:
#                        Country Name Country Code          1960          1961  \
# 1       Africa Eastern and Southern          AFE  1.929944e+10  1.970954e+10
# 3        Africa Western and Central          AFW  1.040428e+10  1.112805e+10
# 13                        Australia          AUS  1.860679e+10  1.968306e+10
# 14                          Austria          AUT  6.592694e+09  7.311750e+09
# 16                          Burundi          BDI  1.960000e+08  2.030000e+08
# ..                              ...          ...           ...           ...
# 253  St. Vincent and the Grenadines          VCT  1.306656e+07  1.399988e+07
# 259                           World          WLD  1.387920e+12  1.444480e+12
# 263                    South Africa          ZAF  7.575397e+09  7.972997e+09
# 264                          Zambia          ZMB  7.130000e+08  6.962857e+08
# 265                        Zimbabwe          ZWE  1.052990e+09  1.096647e+09
#
# ...

# %%
y
# Out:
#                     Country Name Country Code        1960        1961  \
# 1                    Afghanistan          AFG     8996967     9169406
# 2    Africa Eastern and Southern          AFE   130836765   134159786
# 3     Africa Western and Central          AFW    96396419    98407221
# 4                        Albania          ALB     1608800     1659800
# 5                        Algeria          DZA    11057864    11336336
# ..                           ...          ...         ...         ...
# 262           West Bank and Gaza          PSE          ..          ..
# 263                        World          WLD  3032156070  3071596055
# 264                  Yemen, Rep.          YEM     5315351     5393034
# 265                       Zambia          ZMB     3070780     3164330
# 266                     Zimbabwe          ZWE     3776679     3905038
#
#            1962        1963        1964        1965        1966        1967  \
# ...

# %%
x = x.melt(id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='GDP' )
y = y.melt(id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='Population')

# %%
x.head()
# Out:
#                   Country Name Country Code  Year           GDP
# 0  Africa Eastern and Southern          AFE  1960  1.929944e+10
# 1   Africa Western and Central          AFW  1960  1.040428e+10
# 2                    Australia          AUS  1960  1.860679e+10
# 3                      Austria          AUT  1960  6.592694e+09
# 4                      Burundi          BDI  1960  1.960000e+08

# %%
y.head()
# Out:
#                   Country Name Country Code  Year Population
# 0                  Afghanistan          AFG  1960    8996967
# 1  Africa Eastern and Southern          AFE  1960  130836765
# 2   Africa Western and Central          AFW  1960   96396419
# 3                      Albania          ALB  1960    1608800
# 4                      Algeria          DZA  1960   11057864

# %%
corr_data = pd.merge(x, y, how="inner")
corr_data = corr_data[corr_data['Year'].astype(int) >= 2001]

mask = ~corr_data['Population'].str.replace(',', '', regex=False).str.strip().str.fullmatch(r'\d+(\.\d+)?')

corr_data['Population'] = pd.to_numeric(corr_data['Population'].str.replace(',', '', regex=False), errors='coerce')

# %%
corr_data.head()


corr_data['Population'] = pd.to_numeric(corr_data['Population'])
corr_data.drop(labels=['Country Name', 'Country Code', 'Year'], axis=1, inplace=True)
corr_data.head()
# Out:
#                GDP   Population
# 4879  2.586600e+11  408522129.0
# 4880  1.480120e+11  274433894.0
# 4881  3.790840e+11   19413000.0
# 4882  1.973380e+11    8042293.0
# 4883  8.767947e+08    6525546.0

# %%
corr_matrix = corr_data.corr()
corr_matrix
# Out:
#                  GDP  Population
# GDP         1.000000    0.692586
# Population  0.692586    1.000000
